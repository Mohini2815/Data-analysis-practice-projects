# %% [markdown]
# # Crypto Market Dataset Analysis

# %% [markdown]
# **Objective**
# - Forecasting future price movements, understanding market volatility, and analyzing sentiments's impact.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:\\Users\\mohin\\Downloads\\Crypto_Market.csv")
df
# Out:
#             Date Coin_Name   Open_Price  Close_Price   High_Price  \
# 0     03-09-2023    Ripple     1.178283     1.190455     1.209325
# 1     09-03-2023  Ethereum  1029.666155  1028.198225  1049.940515
# 2     30-03-2023   Cardano     0.156767     0.158515     0.158515
# 3     03-03-2023  Dogecoin     0.055513     0.055788     0.056129
# 4     04-02-2023   Cardano     0.286946     0.288630     0.297346
# ...          ...       ...          ...          ...          ...
# 2995  22-05-2023  Dogecoin     0.131807     0.130330     0.132704
# 2996  24-03-2023  Litecoin    63.239263    62.954663    63.901432
# 2997  25-05-2023    Solana   112.961664   111.429633   113.855490
# 2998  26-03-2023    Ripple     0.291611     0.289120     0.294825
# 2999  20-09-2023   Cardano     0.309670     0.311373     0.314636
#
#         Low_Price  Volume_Traded_USD  Market_Cap_USD  Price_Change_Percent  \
# 0        1.169658       5.866778e+07    6.493389e+10              1.032987
# 1     1011.826335       1.944468e+08    1.140000e+11             -0.142564
# 2        0.156185       1.934877e+07    5.283837e+09              1.114990
# 3        0.055089       1.717137e+07    9.762956e+09              0.496067
# 4        0.277746       2.923033e+07    9.620999e+09              0.586735
# ...           ...                ...             ...                   ...
# 2995     0.129449       3.434216e+07    2.280770e+10             -1.121071
# 2996    62.886032       1.669579e+07    4.896474e+09             -0.450036
# 2997   108.894538       1.210241e+08    5.571482e+10             -1.356240
# 2998     0.281803       6.649369e+07    1.577018e+10             -0.854381
# 2999     0.306500       2.210790e+07    1.037909e+10              0.549834
#
#       Daily_Volatility_Percent  Transactions_Count  Active_Addresses  \
# 0                     3.366520            121856.0            646912
# 1                     3.701606            217083.0            576459
# 2                     1.486296            119516.0            520454
# 3                     1.873866            147418.0            603550
# 4                     6.830590            197399.0            672366
# ...                        ...                 ...               ...
# 2995                  2.469463            182187.0            638653
# 2996                  1.605648            128884.0            718185
# 2997                  4.391713            161683.0            665059
# 2998                  4.465494            109315.0            759188
# 2999                  2.627237            140117.0            631732
#
#       Sentiment_Score  Network_Fee_USD
# 0               0.011             1.77
# 1              -0.042             4.70
# 2               0.229             0.63
# 3              -0.026             2.16
# 4               0.025             3.47
# ...               ...              ...
# 2995           -0.016             3.78
# 2996            0.016             1.82
# 2997            0.139             3.89
# 2998           -0.145             3.86
# 2999           -0.077             1.94
#
# [3000 rows x 14 columns]

# %%
df.head()
# Out:
#          Date Coin_Name   Open_Price  Close_Price   High_Price    Low_Price  \
# 0  03-09-2023    Ripple     1.178283     1.190455     1.209325     1.169658
# 1  09-03-2023  Ethereum  1029.666155  1028.198225  1049.940515  1011.826335
# 2  30-03-2023   Cardano     0.156767     0.158515     0.158515     0.156185
# 3  03-03-2023  Dogecoin     0.055513     0.055788     0.056129     0.055089
# 4  04-02-2023   Cardano     0.286946     0.288630     0.297346     0.277746
#
#    Volume_Traded_USD  Market_Cap_USD  Price_Change_Percent  \
# 0       5.866778e+07    6.493389e+10              1.032987
# 1       1.944468e+08    1.140000e+11             -0.142564
# 2       1.934877e+07    5.283837e+09              1.114990
# 3       1.717137e+07    9.762956e+09              0.496067
# 4       2.923033e+07    9.620999e+09              0.586735
#
#    Daily_Volatility_Percent  Transactions_Count  Active_Addresses  \
# 0                  3.366520            121856.0            646912
# 1                  3.701606            217083.0            576459
# 2                  1.486296            119516.0            520454
# 3                  1.873866            147418.0            603550
# 4                  6.830590            197399.0            672366
#
#    Sentiment_Score  Network_Fee_USD
# 0            0.011             1.77
# 1           -0.042             4.70
# 2            0.229             0.63
# 3           -0.026             2.16
# 4            0.025             3.47

# %%
df.tail()
# Out:
#             Date Coin_Name  Open_Price  Close_Price  High_Price   Low_Price  \
# 2995  22-05-2023  Dogecoin    0.131807     0.130330    0.132704    0.129449
# 2996  24-03-2023  Litecoin   63.239263    62.954663   63.901432   62.886032
# 2997  25-05-2023    Solana  112.961664   111.429633  113.855490  108.894538
# 2998  26-03-2023    Ripple    0.291611     0.289120    0.294825    0.281803
# 2999  20-09-2023   Cardano    0.309670     0.311373    0.314636    0.306500
#
#       Volume_Traded_USD  Market_Cap_USD  Price_Change_Percent  \
# 2995       3.434216e+07    2.280770e+10             -1.121071
# 2996       1.669579e+07    4.896474e+09             -0.450036
# 2997       1.210241e+08    5.571482e+10             -1.356240
# 2998       6.649369e+07    1.577018e+10             -0.854381
# 2999       2.210790e+07    1.037909e+10              0.549834
#
#       Daily_Volatility_Percent  Transactions_Count  Active_Addresses  \
# 2995                  2.469463            182187.0            638653
# 2996                  1.605648            128884.0            718185
# 2997                  4.391713            161683.0            665059
# 2998                  4.465494            109315.0            759188
# 2999                  2.627237            140117.0            631732
#
#       Sentiment_Score  Network_Fee_USD
# 2995           -0.016             3.78
# 2996            0.016             1.82
# 2997            0.139             3.89
# 2998           -0.145             3.86
# 2999           -0.077             1.94

# %%
# diff between high price and low price
# what is the use of coin price and close price
# how to get volume traded usd abd market cap usd in round up
# objective
# drop duplicates also make change in dataset

# %%
df['Volume_Traded_USD'] = df['Volume_Traded_USD'].round(2)

# %%
df['Market_Cap_USD'] = df['Market_Cap_USD'].round(2)

# %%
df.head()
# Out:
#          Date Coin_Name   Open_Price  Close_Price   High_Price    Low_Price  \
# 0  03-09-2023    Ripple     1.178283     1.190455     1.209325     1.169658
# 1  09-03-2023  Ethereum  1029.666155  1028.198225  1049.940515  1011.826335
# 2  30-03-2023   Cardano     0.156767     0.158515     0.158515     0.156185
# 3  03-03-2023  Dogecoin     0.055513     0.055788     0.056129     0.055089
# 4  04-02-2023   Cardano     0.286946     0.288630     0.297346     0.277746
#
#    Volume_Traded_USD  Market_Cap_USD  Price_Change_Percent  \
# 0       5.866778e+07    6.493389e+10              1.032987
# 1       1.944468e+08    1.140000e+11             -0.142564
# 2       1.934877e+07    5.283837e+09              1.114990
# 3       1.717137e+07    9.762956e+09              0.496067
# 4       2.923033e+07    9.620999e+09              0.586735
#
#    Daily_Volatility_Percent  Transactions_Count  Active_Addresses  \
# 0                  3.366520            121856.0            646912
# 1                  3.701606            217083.0            576459
# 2                  1.486296            119516.0            520454
# 3                  1.873866            147418.0            603550
# 4                  6.830590            197399.0            672366
#
#    Sentiment_Score  Network_Fee_USD
# 0            0.011             1.77
# 1           -0.042             4.70
# 2            0.229             0.63
# 3           -0.026             2.16
# 4            0.025             3.47

# %%
df.duplicated().sum()
# Out:
# 44

# %%
print('Number of rows before removing duplicates = ',len(df))
# Out:
# Number of rows before removing duplicates =  3000

# %%
print('Number of duplicate rows found ',df.duplicated().sum())
# Out:
# Number of duplicate rows found  44

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date                          0
# Coin_Name                     0
# Open_Price                    0
# Close_Price                   0
# High_Price                    0
# Low_Price                     0
# Volume_Traded_USD           117
# Market_Cap_USD                0
# Price_Change_Percent          0
# Daily_Volatility_Percent      0
# Transactions_Count          120
# Active_Addresses              0
# Sentiment_Score             120
# Network_Fee_USD               0
# dtype: int64

# %%
# Imputation Strategy: Group-wise Median ---
# Calculate the median Volume_Traded_USD for each Coin_Name
coin_median_volume = df.groupby('Coin_Name')['Volume_Traded_USD'].median()
df['Volume_Traded_USD'] = df['Volume_Traded_USD']

# Fill missing values in 'Volume_Traded_USD' using the corresponding coin's median
df['Volume_Traded_USD'] = df.apply(
    lambda row: coin_median_volume[row['Coin_Name']] if pd.isna(row['Volume_Traded_USD']) else row['Volume_Traded_USD'],
    axis=1
)

# --- Verification (and fallback for edge cases) ---
# If any values are still missing, fill them with the overall median
remaining_na = df['Volume_Traded_USD'].isnull().sum()
if remaining_na > 0:
    overall_median_volume = df['Volume_Traded_USD'].median()
    df['Volume_Traded_USD'].fillna(overall_median_volume, inplace=True)

# %%
# calculate median 
median_count = df['Transactions_Count'].median()
df['Transactions_Count'].fillna(median_count,inplace=True)
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_15072\164092977.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Transactions_Count'].fillna(median_count,inplace=True)

# %%
sns.boxplot(df['Sentiment_Score'])
# Out:
# <Axes: ylabel='Sentiment_Score'>

# %%
median_score = df['Sentiment_Score'].median()
df['Sentiment_Score'].fillna(median_score,inplace=True)
# Out:
# C:\Users\mohin\AppData\Local\Temp\ipykernel_15072\2146785198.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sentiment_Score'].fillna(median_score,inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                        0
# Coin_Name                   0
# Open_Price                  0
# Close_Price                 0
# High_Price                  0
# Low_Price                   0
# Volume_Traded_USD           0
# Market_Cap_USD              0
# Price_Change_Percent        0
# Daily_Volatility_Percent    0
# Transactions_Count          0
# Active_Addresses            0
# Sentiment_Score             0
# Network_Fee_USD             0
# dtype: int64

# %%
df['High_Price'].max()
# Out:
# 159657.4264

# %%
df['Low_Price'].max()
# Out:
# 148734.3957

# %%
df['daily_price_range'] = df['High_Price'] - df['Low_Price']
df['daily_price_range'].sort_values(ascending=False).head(10)
# Out:
# 481     18540.80160
# 550     14941.44100
# 2158    14805.40780
# 1626    11909.48305
# 2515    10923.03070
# 1325     9889.50572
# 2189     9007.72417
# 1629     8493.94790
# 2365     7228.86285
# 1781     6506.88240
# Name: daily_price_range, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2956 entries, 0 to 2999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      2956 non-null   object
#  1   Coin_Name                 2956 non-null   object
#  2   Open_Price                2956 non-null   float64
#  3   Close_Price               2956 non-null   float64
#  4   High_Price                2956 non-null   float64
#  5   Low_Price                 2956 non-null   float64
#  6   Volume_Traded_USD         2956 non-null   float64
#  7   Market_Cap_USD            2956 non-null   float64
#  8   Price_Change_Percent      2956 non-null   float64
#  9   Daily_Volatility_Percent  2956 non-null   float64
#  10  Transactions_Count        2956 non-null   float64
#  11  Active_Addresses          2956 non-null   int64
#  12  Sentiment_Score           2956 non-null   float64
#  13  Network_Fee_USD           2956 non-null   float64
#  14  daily_price_range         2956 non-null   float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 369.5+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'],format='mixed')
df['Date']
# Out:
# 0      2023-03-09
# 1      2023-09-03
# 2      2023-03-30
# 3      2023-03-03
# 4      2023-04-02
#           ...
# 2995   2023-05-22
# 2996   2023-03-24
# 2997   2023-05-25
# 2998   2023-03-26
# 2999   2023-09-20
# Name: Date, Length: 2956, dtype: datetime64[ns]

# %%
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
df['weekday'] = df['Date'].dt.day_name()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2956 entries, 0 to 2999
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      2956 non-null   datetime64[ns]
#  1   Coin_Name                 2956 non-null   object
#  2   Open_Price                2956 non-null   float64
#  3   Close_Price               2956 non-null   float64
#  4   High_Price                2956 non-null   float64
#  5   Low_Price                 2956 non-null   float64
#  6   Volume_Traded_USD         2956 non-null   float64
#  7   Market_Cap_USD            2956 non-null   float64
#  8   Price_Change_Percent      2956 non-null   float64
#  9   Daily_Volatility_Percent  2956 non-null   float64
#  10  Transactions_Count        2956 non-null   float64
#  11  Active_Addresses          2956 non-null   int64
#  12  Sentiment_Score           2956 non-null   float64
#  13  Network_Fee_USD           2956 non-null   float64
#  14  daily_price_range         2956 non-null   float64
#  15  Open_Price_Display        2956 non-null   object
#  16  Day                       2956 non-null   int32
#  17  Month                     2956 non-null   int32
#  18  Year                      2956 non-null   int32
#  19  weekday                   2956 non-null   object
# dtypes: datetime64[ns](1), float64(12), int32(3), int64(1), object(3)
# memory usage: 450.3+ KB

# %%
df.drop(['Date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Coin_Name  Open_Price  Close_Price  High_Price  Low_Price  \
# 0    Ripple      1.1800       1.1905      1.2093     1.1697
# 1  Ethereum   1029.6700    1028.1982   1049.9405  1011.8263
# 2   Cardano      0.1600       0.1585      0.1585     0.1562
# 3  Dogecoin      0.0600       0.0558      0.0561     0.0551
# 4   Cardano      0.2900       0.2886      0.2973     0.2777
#
#    Volume_Traded_USD    Market_Cap_USD  Price_Change_Percent  \
# 0      58667783.7700  64933894853.0000                1.0330
# 1     194446772.2000 114000000000.0000               -0.1426
# 2      19348767.7800   5283837217.0000                1.1150
# 3      17171365.0300   9762955946.0000                0.4961
# 4      29230326.1000   9620998862.0000                0.5867
#
#    Daily_Volatility_Percent  Transactions_Count  Active_Addresses  \
# 0                    3.3665         121856.0000            646912
# 1                    3.7016         217083.0000            576459
# 2                    1.4863         119516.0000            520454
# 3                    1.8739         147418.0000            603550
# 4                    6.8306         197399.0000            672366
#
#    Sentiment_Score  Network_Fee_USD  daily_price_range Open_Price_Display  \
# 0           0.0110           1.7700             0.0397             1.1800
# 1          -0.0420           4.7000            38.1142         1,029.6700
# 2           0.2290           0.6300             0.0023             0.1600
# 3          -0.0260           2.1600             0.0010             0.0600
# 4           0.0250           3.4700             0.0196             0.2900
#
#    Day  Month  Year   weekday
# 0    9      3  2023  Thursday
# 1    3      9  2023    Sunday
# 2   30      3  2023  Thursday
# 3    3      3  2023    Friday
# 4    2      4  2023    Sunday

# %%
df.columns
# Out:
# Index(['Coin_Name', 'Open_Price', 'Close_Price', 'High_Price', 'Low_Price',
#        'Volume_Traded_USD', 'Market_Cap_USD', 'Price_Change_Percent',
#        'Daily_Volatility_Percent', 'Transactions_Count', 'Active_Addresses',
#        'Sentiment_Score', 'Network_Fee_USD', 'daily_price_range',
#        'Open_Price_Display', 'Day', 'Month', 'Year', 'weekday'],
#       dtype='object')

# %%
df.shape
# Out:
# (2956, 19)

# %%
df.nunique()
# Out:
# Coin_Name                     20
# Open_Price                  1854
# Close_Price                 2955
# High_Price                  2956
# Low_Price                   2956
# Volume_Traded_USD           2848
# Market_Cap_USD              2715
# Price_Change_Percent        2956
# Daily_Volatility_Percent    2955
# Transactions_Count          2806
# Active_Addresses            2949
# Sentiment_Score              674
# Network_Fee_USD              521
# daily_price_range           2947
# Open_Price_Display          1854
# Day                           29
# Month                         12
# Year                           1
# weekday                        7
# dtype: int64

# %%
df.describe(include='all')
# Out:
#        Coin_Name  Open_Price  Close_Price  High_Price   Low_Price  \
# count       2956   2956.0000    2956.0000   2956.0000   2956.0000
# unique        20         NaN          NaN         NaN         NaN
# top       Ripple         NaN          NaN         NaN         NaN
# freq         289         NaN          NaN         NaN         NaN
# mean         NaN   4600.8342    4600.5886   4694.6981   4506.7466
# std          NaN  15302.4174   15293.2956  15632.3357  14939.6903
# min          NaN      0.0500       0.0479      0.0490      0.0455
# 25%          NaN      0.4700       0.4696      0.4797      0.4613
# 50%          NaN     10.7450      10.7333     10.8930     10.5740
# 75%          NaN    103.3125     103.7842    106.0414    102.1732
# max          NaN 152674.1200  159657.4264 159657.4264 148734.3957
#
#         Volume_Traded_USD     Market_Cap_USD  Price_Change_Percent  \
# count           2956.0000          2956.0000             2956.0000
# unique                NaN                NaN                   NaN
# top                   NaN                NaN                   NaN
# freq                  NaN                NaN                   NaN
# mean       185346421.5559  136513426454.9279               -0.0517
# std        422168826.9774  351686584036.7616                1.3145
# min           445846.7900    3421233984.0000               -7.1939
# 25%         20036576.9275    9868435552.5000               -0.6842
# 50%         31939935.9550   17672778896.0000               -0.0274
# 75%         91136969.8500   66898945556.7500                0.6286
# max       8816560915.0000 5390000000000.0000                4.5740
#
#         Daily_Volatility_Percent  Transactions_Count  Active_Addresses  \
# count                  2956.0000           2956.0000         2956.0000
# unique                       NaN                 NaN               NaN
# top                          NaN                 NaN               NaN
# freq                         NaN                 NaN               NaN
# mean                      4.1845         150102.4198       702482.7777
# std                       4.0860          39699.1576       120896.5974
# min                       0.0718          23830.0000       290515.0000
# 25%                       1.8865         123755.0000       621442.2500
# 50%                       3.2095         150223.5000       701406.0000
# 75%                       5.2294         176698.7500       785619.0000
# max                      54.8864         279091.0000      1091586.0000
#
#         Sentiment_Score  Network_Fee_USD  daily_price_range  \
# count         2956.0000        2956.0000          2956.0000
# unique              NaN              NaN                NaN
# top                 NaN              NaN                NaN
# freq                NaN              NaN                NaN
# mean             0.0012           2.5615           187.9515
# std              0.1510           1.1767           892.6061
# min             -0.5430           0.0100             0.0002
# 25%             -0.0920           1.7800             0.0160
# 50%              0.0010           2.5600             0.3061
# 75%              0.1013           3.3400             4.2367
# max              0.6030           6.8700         18540.8016
#
#        Open_Price_Display       Day     Month      Year weekday
# count                2956 2956.0000 2956.0000 2956.0000    2956
# unique               1854       NaN       NaN       NaN       7
# top                0.0600       NaN       NaN       NaN  Friday
# freq                   59       NaN       NaN       NaN     445
# mean                  NaN   15.1225    5.8599 2023.0000     NaN
# std                   NaN    9.0373    3.1402    0.0000     NaN
# min                   NaN    1.0000    1.0000 2023.0000     NaN
# 25%                   NaN    7.0000    3.0000 2023.0000     NaN
# 50%                   NaN   15.0000    6.0000 2023.0000     NaN
# 75%                   NaN   23.0000    8.0000 2023.0000     NaN
# max                   NaN   31.0000   12.0000 2023.0000     NaN

# %%
df['Coin_Name'].value_counts()
# Out:
# Coin_Name
# Ripple       289
# Litecoin     289
# Polygon      289
# Polkadot     289
# Ethereum     288
# Solana       287
# Bitcoin      287
# Dogecoin     285
# Chainlink    284
# Cardano      282
# cardano       14
# chainlink     13
# bitcoin       12
# polkadot      10
# dogecoin       9
# ethereum       7
# solana         6
# ripple         6
# polygon        5
# litecoin       5
# Name: count, dtype: int64

# %%
df['Open_Price'] = df['Open_Price'].round(2)
df.head()
# Out:
#   Coin_Name  Open_Price  Close_Price  High_Price  Low_Price  \
# 0    Ripple      1.1800       1.1905      1.2093     1.1697
# 1  Ethereum   1029.6700    1028.1982   1049.9405  1011.8263
# 2   Cardano      0.1600       0.1585      0.1585     0.1562
# 3  Dogecoin      0.0600       0.0558      0.0561     0.0551
# 4   Cardano      0.2900       0.2886      0.2973     0.2777
#
#    Volume_Traded_USD    Market_Cap_USD  Price_Change_Percent  \
# 0      58667783.7700  64933894853.0000                1.0330
# 1     194446772.2000 114000000000.0000               -0.1426
# 2      19348767.7800   5283837217.0000                1.1150
# 3      17171365.0300   9762955946.0000                0.4961
# 4      29230326.1000   9620998862.0000                0.5867
#
#    Daily_Volatility_Percent  Transactions_Count  Active_Addresses  \
# 0                    3.3665         121856.0000            646912
# 1                    3.7016         217083.0000            576459
# 2                    1.4863         119516.0000            520454
# 3                    1.8739         147418.0000            603550
# 4                    6.8306         197399.0000            672366
#
#    Sentiment_Score  Network_Fee_USD  daily_price_range Open_Price_Display  \
# 0           0.0110           1.7700             0.0397             1.1800
# 1          -0.0420           4.7000            38.1142         1,029.6700
# 2           0.2290           0.6300             0.0023             0.1600
# 3          -0.0260           2.1600             0.0010             0.0600
# 4           0.0250           3.4700             0.0196             0.2900
#
#    Day  Month  Year   weekday
# 0    9      3  2023  Thursday
# 1    3      9  2023    Sunday
# 2   30      3  2023  Thursday
# 3    3      3  2023    Friday
# 4    2      4  2023    Sunday

# %%
df['Open_Price_Display'] = df['Open_Price'].apply(lambda x:f'{x:,.4f}')

print(df[['Open_Price_Display']].head())
# Out:
#   Open_Price_Display
# 0             1.1800
# 1         1,029.6700
# 2             0.1600
# 3             0.0600
# 4             0.2900

# %%
# set the defalut display to 4 decimal places
pd.set_option('display.float_format','{:.4f}'.format)

# now when you print the dataframe the prices will look cleaner
print(df[['Coin_Name','Open_Price']].head(20))
# Out:
#     Coin_Name  Open_Price
# 0      Ripple      1.1800
# 1    Ethereum   1029.6700
# 2     Cardano      0.1600
# 3    Dogecoin      0.0600
# 4     Cardano      0.2900
# 5    Litecoin     59.6400
# 6     Cardano      0.1900
# 7     Cardano      0.3100
# 8     Polygon      0.3900
# 9   Chainlink      7.5200
# 10   Litecoin     60.3000
# 11    Cardano      0.3000
# 12   Litecoin    136.3200
# 13     Solana     39.2500
# 14   Litecoin    232.3000
# 15   Ethereum   1702.2600
# 16   Dogecoin      0.0700
# 17    Bitcoin  18181.8200
# 18   Dogecoin      0.1000
# 19   Ethereum   1024.1000

# %%
df_long = pd.melt(
    df,
    id_vars = ['Coin_Name'],
    value_vars = ['High_Price','Low_Price'],
    var_name = 'Price Type',
    value_name = 'Price'
)

plt.figure(figsize = (14,8))
sns.violinplot(x='Coin_Name',y='Price',hue='Price Type',data = df_long,split=True,inner='quartile',
               palette = {'High_Price':'darkred','Low_Price':'darkblue'})

plt.title('violin plot of high score vs low price')
plt.xlabel('Coin name',fontsize = 12)
plt.ylabel('Price',fontsize=12)
plt.xticks(rotation=45,ha='right')
plt.legend(title='Price Type')

plt.tight_layout()

# %%
prices_summary = df.groupby('Coin_Name')[['Open_Price','Close_Price']].mean().round(2)
print(prices_summary)
# Out:
#            Open_Price  Close_Price
# Coin_Name
# Bitcoin    42771.5600   42766.1900
# Cardano        0.3400       0.3400
# Chainlink     20.4400      20.4500
# Dogecoin       0.0900       0.0900
# Ethereum    2908.8600    2912.8500
# Litecoin      87.1100      87.1900
# Polkadot       7.5100       7.5100
# Polygon        0.8000       0.8000
# Ripple         1.0200       1.0200
# Solana        70.0600      70.0000
# bitcoin    34301.1400   34281.2000
# cardano        0.3500       0.3500
# chainlink     21.2400      21.3800
# dogecoin       0.0800       0.0800
# ethereum    2891.2200    2876.8900
# litecoin      76.7900      76.7400
# polkadot       6.1300       6.1700
# polygon        0.7300       0.7200
# ripple         1.4000       1.4000
# solana        62.7300      62.4100

# %%
active_add = df.groupby('Coin_Name')['Active_Addresses'].sum().reset_index()
max_active_add = active_add.loc[active_add['Active_Addresses'].idxmax()]

counts = df.groupby('Coin_Name')['Transactions_Count'].sum().reset_index()
highest_transaction_count = counts.loc[counts['Transactions_Count'].idxmax()]

# %%
max_active_add
# Out:
# Coin_Name            Ethereum
# Active_Addresses    205132874
# Name: 4, dtype: object

# %%
highest_transaction_count
# Out:
# Coin_Name                 Ethereum
# Transactions_Count   44648748.0000
# Name: 4, dtype: object

# %%
plt.figure(figsize=(30,10))
ax=sns.histplot(df['Coin_Name'],bins=20,kde=True)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('coin name Distribution')
plt.xlabel('coin name')
plt.ylabel('Distributions')
plt.show()

# %%
sns.countplot(df['Coin_Name'])
# Out:
# <Axes: xlabel='count', ylabel='Coin_Name'>

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.lineplot(data=df,
            x='weekday',y='Open_Price',hue='Coin_Name',marker='o')
plt.title('day wise open price for coins')
plt.xlabel('weekday')
plt.ylabel('open price')
plt.legend(title='Coin_Name')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
df_melted = df.melt(
    id_vars = ['weekday','Coin_Name'],
    value_vars = ['High_Price','Low_Price'],
    var_name = 'Price Metric',
    value_name = 'Price'
)

sns.set_style('whitegrid')
g = sns.catplot(data=df_melted,
               x='weekday',
               y='Price',
               hue='Price Metric',
               col='Coin_Name',
               kind='bar',
               palette={'High_Price':'green','Low_Price':'red'},
               height=5,
               aspect=1.5
)
g.fig.suptitle('day wise high vs low price comparision',y=1.03,fontsize=16)
g.set_axis_labels('weekday','Price')
# g.set_titles({'col_name'})
for ax in g.axes.flat:
    for item in ax.get_xticklabels():
        item.set_rotation(45)
    ax.ticklabel_format(style='plain',axis='y')

plt.tight_layout(rect=[0,0,1,0.98])
